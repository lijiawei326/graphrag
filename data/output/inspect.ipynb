# %%
import pandas as pd

# %%
df = pd.read_parquet('./entities.parquet')

# %%
df.sort_values('human_readable_id')
# Out:
#                                       id  human_readable_id  \
# 45  58ac8a3f-7a32-4ef2-87e4-f190c0b883a9                  0
# 48  d6cff8dc-f024-4be7-8d47-fe950fd9c922                  1
# 50  5510bff2-7097-429c-b972-7fe0aed70163                  2
# 49  1c5baa4b-407a-4c38-8c0a-637d2adc5327                  3
# 51  a0ab87bb-a954-42e3-ae70-16f6d7d45e8d                  4
# 55  40086a42-6249-49ac-976e-1ac1be2630e7                  5
# 38  4a5eb45a-400a-4096-92f9-359c907339ef                  6
# 15  f2f66b48-aacc-49fc-868d-e2a74c268218                  7
# 24  5fb5f94e-723b-4981-bb65-400896588d55                  8
# 29  35d0d208-eae6-4763-8227-d996f003875f                  9
# 30  29067c9e-0567-4a37-8326-23f5c6145ae8                 10
# 44  9c6f8344-d5ff-4696-b88f-c633b37b8a57                 11
# 23  3e8bb4f2-655e-451a-a449-043741e7ba8d                 12
# 46  96dbd108-356c-4907-9a2a-61765fb4f9af                 13
# 26  3fba13a1-0bad-4012-bf6d-9db2fda0645d                 14
# ...
